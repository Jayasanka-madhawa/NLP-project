# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import cv2

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train[0].dtype
# Out:
# dtype('uint8')

# %%
y_train.shape
# Out:
# (60000,)

# %%
y_train[0].dtype
# Out:
# dtype('uint8')

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(784,), activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 883us/step - loss: 0.4899 - accuracy: 0.8770
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3064 - accuracy: 0.9156
# Epoch 3/5
# 1875/1875 [==============================] - 2s 893us/step - loss: 0.2855 - accuracy: 0.9206
# Epoch 4/5
# 1875/1875 [==============================] - 2s 887us/step - loss: 0.2749 - accuracy: 0.9244
# Epoch 5/5
# 1875/1875 [==============================] - 2s 830us/step - loss: 0.2678 - accuracy: 0.9261

# %%
model.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 [==============================] - 0s 773us/step - loss: 0.2687 - accuracy: 0.9256
# [0.2687094211578369, 0.925599992275238]

# %%
y_predicted = model.predict(X_test_flattened)
y_predicted[0]
# Out:
# array([1.70785897e-05, 5.67102997e-11, 4.56745656e-05, 8.96713138e-03,
#        1.23680911e-06, 1.07491505e-04, 6.80103529e-10, 7.72940159e-01,
#        7.32873232e-05, 5.54263592e-04], dtype=float32)

# %%
plt.matshow(X_test[0])

# %%
np.argmax(y_predicted[0])
# Out:
# 7

# %% [markdown]
# # my edit

# %%
testimg=cv2.imread("segmented_leter{}.png".format(0))
testimg = testimg[40:250,112:330]
img_float32 = np.float32(testimg)
gray_image = cv2.cvtColor(img_float32, cv2.COLOR_BGR2GRAY)
testimg=cv2.resize(gray_image,(28,28))
testimg=testimg/255
plt.imshow(testimg)
testimg.dtype
testimg.shape
# Out:
# (28, 28)

# %%
testimg
# Out:
# array([[0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#         0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#         0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#         0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#         0.11958823, 0.11958823, 0.11958823, 0.11958823, 0.11958823,
#         0.11958823, 0.11958823, 0.11958823],
#        [0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#         0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#         0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#         0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#         0.11958823, 0.11958823, 0.11958823, 0.11958823, 0.11958823,
#         0.11958823, 0.11958823, 0.11958823],
#        [0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#         0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
# ...

# %%
im_array=np.array([testimg])
im_array
# Out:
# array([[[0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#          0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#          0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#          0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#          0.11958823, 0.11958823, 0.11958823, 0.11958823, 0.11958823,
#          0.11958823, 0.11958823, 0.11958823],
#         [0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#          0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#          0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#          0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#          0.11958823, 0.11958823, 0.11958823, 0.11958823, 0.11958823,
#          0.11958823, 0.11958823, 0.11958823],
#         [0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#          0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
# ...

# %%
#np.set_printoptions(threshold=np.inf)
#im_array = np.vstack([im_array, [testimg]])

# %%
im_array.shape
# Out:
# (1, 28, 28)

# %%
for i in range(1,3):
    print(i)
    testimg=cv2.imread("segmented_leter{}.png".format(i))
    testimg = testimg[40:250,112:330]
    img_float32 = np.float32(testimg)
    gray_image = cv2.cvtColor(img_float32, cv2.COLOR_BGR2GRAY)
    testimg=cv2.resize(gray_image,(28,28))
    testimg=testimg/255
    #print(testimg)
    #np.append(im_array,[testimg],axis=0)
    im_array = np.vstack([im_array, [testimg]])
    print(im_array)
    
print(type(im_array))
len(im_array)
# Out:
# 1
# [[[0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.11958823 0.11958823 0.11958823 0.11958823
#    0.11958823 0.11958823 0.11958823 0.11958823]
#   [0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.11958823 0.11958823 0.11958823 0.11958823
#    0.11958823 0.11958823 0.11958823 0.11958823]
#   [0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.11958823 0.11958823 0.11958823 0.11958823
#    0.11958823 0.11958823 0.11958823 0.11958823]
# ...

# %%
#len(im_array)
print(im_array.ndim)
im_array.shape
# Out:
# 3
# (3, 28, 28)

# %%
np.set_printoptions(threshold=np.inf)
print(im_array)
# Out:
# [[[0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.11958823 0.11958823 0.11958823 0.11958823
#    0.11958823 0.11958823 0.11958823 0.11958823]
#   [0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.11958823 0.11958823 0.11958823 0.11958823
#    0.11958823 0.11958823 0.11958823 0.11958823]
#   [0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.8445019  0.8445019  0.8445019  0.8445019
#    0.8445019  0.8445019  0.11958823 0.11958823 0.11958823 0.11958823
#    0.11958823 0.11958823 0.11958823 0.11958823]
# ...

# %% [markdown]
# # predict

# %%
im_array_flattened = im_array.reshape(len(im_array), 28*28)

# %%
im_array_flattened[0]
# Out:
# array([0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#        0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#        0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#        0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#        0.11958823, 0.11958823, 0.11958823, 0.11958823, 0.11958823,
#        0.11958823, 0.11958823, 0.11958823, 0.8445019 , 0.8445019 ,
#        0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#        0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#        0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#        0.8445019 , 0.8445019 , 0.8445019 , 0.11958823, 0.11958823,
#        0.11958823, 0.11958823, 0.11958823, 0.11958823, 0.11958823,
#        0.11958823, 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#        0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
#        0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 , 0.8445019 ,
# ...

# %%
im_array_flattened[0].shape
# Out:
# (784,)

# %%
predicted = model.predict(im_array_flattened)
predicted[0]
# Out:
# array([1.1064167e-32, 1.2684495e-33, 1.1222400e-21, 1.4431062e-16,
#        4.4192638e-38, 7.0301263e-19, 8.0185660e-24, 1.4211283e-24,
#        5.8651283e-29, 5.6830137e-27], dtype=float32)

# %%
np.argmax(predicted[0])
# Out:
# 3
